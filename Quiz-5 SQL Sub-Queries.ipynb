# %% [markdown]
# <a href="https://colab.research.google.com/github/ithapa1/data-visualization/blob/main/Quiz-5%20SQL%20Sub-Queries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SQL Sub-Queries**
# Quiz- 5

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# Now that Authentication is done, I will be looking at the data and play around. I am going to plot all the data related to the austin bikeshare trips. after then, i am also going to figure out the possible most popular second starting station and trips lasted over an hour and were a round trip (started and stopped at the same station).

# %%
# %%bigquery --project data-visualization-338803
# SELECT *
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# LIMIT 10
# Out:
#       trip_id  ... duration_minutes
# 0  9900289692  ...               39
# 1  9900285987  ...               31
# 2  9900285989  ...               31
# 3  9900285991  ...               30
# 4  9900286140  ...               19
# 5  9900286143  ...               17
# 6  9900286171  ...                6
# 7  9900286214  ...                0
# 8  9900286540  ...               12
# 9    13575843  ...               47
#
# [10 rows x 9 columns]

# %%
# %%bigquery --project data-visualization-338803
# SELECT MAX(start_station_name) as second_most_popular
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# WHERE start_station_name != (SELECT MAX(start_station_name) as most_popular_start_station FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`)
# Out:
#                                  second_most_popular
# 0  Zilker Park at Barton Springs & William Barton...

# %%
# %%bigquery --project data-visualization-338803
# SELECT  COUNTIF(duration_minutes>=60) as over_an_hour_duration ,COUNT( start_station_name) as number_of_trips
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# WHERE start_station_name = end_station_name
# Out:
#    over_an_hour_duration  number_of_trips
# 0                  56369           228339

# %%
# %%bigquery --project data-visualization-338803
# SELECT  start_station_name as station_name,  COUNTIF(duration_minutes>=60) as over_an_hour_duration, COUNT( start_station_name) as number_of_trips
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# WHERE start_station_name = end_station_name
# GROUP BY start_station_name
# Out:
#                                 station_name  ...  number_of_trips
# 0                    Toomey Rd @ South Lamar  ...              633
# 1            State Capitol @ 14th & Colorado  ...              910
# 2                           Waller & 6th St.  ...              583
# 3                                 Pease Park  ...              167
# 4    Capital Metro HQ - East 5th at Broadway  ...              635
# ..                                       ...  ...              ...
# 179    Republic Square @ Guadalupe & 4th St.  ...             1090
# 180                               3rd & West  ...             2002
# 181                                 3rd/West  ...              816
# 182                              26th/Nueces  ...              607
# 183                            Nueces & 26th  ...             1425
#
# [184 rows x 3 columns]

# %% [markdown]
# I calculated the possible ways to get the trips lasted over an hour and also for the round trip.
