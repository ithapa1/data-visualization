# %% [markdown]
# <a href="https://colab.research.google.com/github/ithapa1/data-visualization/blob/main/Quiz_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [The stock market graphical view](https://www.bankonyourself.com/wp-content/uploads/market-crash-survey-result-pie-chart.png)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Us stock Market Debt and Market capitalization Adjusted for Nominal GDP!!](https://www.learnbonds.com/wp-content/images/Bond-Market-Size-Article-Chart-1.png)
# ![image.png](data:image/png;base64,...)
