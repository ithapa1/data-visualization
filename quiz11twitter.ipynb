# %% [markdown]
# <a href="https://colab.research.google.com/github/ithapa1/data-visualization/blob/main/quiz11twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.19.3-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 5.7 MB/s
# Installing collected packages: twitter
# Successfully installed twitter-1.19.3

# %% [markdown]
# Requirement already satisfied: twitter in /usr/local/lib/python3.7/dist-packages (1.19.3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp drive/MyDrive/config.py .

# %%
import config
import twitter
CONSUMER_KEY = config.CONSUMER_KEY
CONSUMER_SECRET = config.CONSUMER_SECRET
OAUTH_TOKEN = config.OAUTH_TOKEN
OAUTH_TOKEN_SECRET = config.OAUTH_TOKEN_SECRET
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

mathcs_twitter_api = twitter.Twitter(auth=auth)

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = mathcs_twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = mathcs_twitter_api.trends.place(_id=US_WOE_ID)

for i in range(10):
    print(world_trends[0]['trends'][i]['query'])
# Out:
# Maria
# Scooby
# %E7%BE%BD%E7%94%9F%E3%81%8F%E3%82%93
# Naiara
# Bruna
# %E5%AE%87%E9%87%8E%E3%81%8F%E3%82%93
# Yuzuru
# B%C3%A1rbara
# %E9%8D%B5%E5%B1%B1%E3%81%8F%E3%82%93
# %22O+Arthur%22

# %% [markdown]
# Here, I am going to see what the world is taking about one of my favourite businessman Elon Musk(EM).

# %%
#  Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.
import json


q = '#EM'

count = 1000

# See https://twitter.com/elonmusk

search_results = mathcs_twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = mathcs_twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses, indent=4))
# Out:
# Streaming output truncated to the last 5000 lines.
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1490849908961984512,
#                     "id_str": "1490849908961984512",
#                     "indices": [
#                         102,
#                         125
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                     "url": "https://t.co/WMbrSlobPK",
#                     "display_url": "pic.twitter.com/WMbrSlobPK",
#                     "expanded_url": "https://twitter.com/glitter_2em13/status/1490849911696666625/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 578,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1020,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1080,
#                             "h": 1270,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490849911696666625,
#                     "source_status_id_str": "1490849911696666625",
#                     "source_user_id": 839262857032155137,
#                     "source_user_id_str": "839262857032155137"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490849908961984512,
#                     "id_str": "1490849908961984512",
#                     "indices": [
#                         102,
#                         125
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                     "url": "https://t.co/WMbrSlobPK",
#                     "display_url": "pic.twitter.com/WMbrSlobPK",
#                     "expanded_url": "https://twitter.com/glitter_2em13/status/1490849911696666625/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 578,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1020,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1080,
#                             "h": 1270,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490849911696666625,
#                     "source_status_id_str": "1490849911696666625",
#                     "source_user_id": 839262857032155137,
#                     "source_user_id_str": "839262857032155137"
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1413656686909394947,
#             "id_str": "1413656686909394947",
#             "name": "\ud835\ude4d\ud835\ude56\ud835\ude67\ud835\ude5a \u2661 \u0f80",
#             "screen_name": "WhiteRoses_11",
#             "location": "Canada \ud83c\udde8\ud83c\udde6 ",
#             "description": "Between illusion, desire. desire and peace. I pass.",
#             "url": "https://t.co/FhMyUsK4pM",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/FhMyUsK4pM",
#                             "expanded_url": "https://twitter.com/search?q=From%3A%40WhiteRoses_11/exclude:replies&src=typed_query",
#                             "display_url": "twitter.com/search?q=From%\u2026",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 26229,
#             "friends_count": 360,
#             "listed_count": 61,
#             "created_at": "Sat Jul 10 00:30:09 +0000 2021",
#             "favourites_count": 33010,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 27248,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1490448174980505600/cvAc7_8__normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1490448174980505600/cvAc7_8__normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1413656686909394947/1634761571",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Tue Feb 08 00:48:12 +0000 2022",
#             "id": 1490849911696666625,
#             "id_str": "1490849911696666625",
#             "text": "Stress less and enjoy the best\n                                      \u3002 .\u3002\u25ef*\uff0a\u309c\n\n#em https://t.co/WMbrSlobPK",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "em",
#                         "indices": [
#                             79,
#                             82
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1490849908961984512,
#                         "id_str": "1490849908961984512",
#                         "indices": [
#                             83,
#                             106
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                         "url": "https://t.co/WMbrSlobPK",
#                         "display_url": "pic.twitter.com/WMbrSlobPK",
#                         "expanded_url": "https://twitter.com/glitter_2em13/status/1490849911696666625/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "small": {
#                                 "w": 578,
#                                 "h": 680,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 1020,
#                                 "h": 1200,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1080,
#                                 "h": 1270,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1490849908961984512,
#                         "id_str": "1490849908961984512",
#                         "indices": [
#                             83,
#                             106
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                         "url": "https://t.co/WMbrSlobPK",
#                         "display_url": "pic.twitter.com/WMbrSlobPK",
#                         "expanded_url": "https://twitter.com/glitter_2em13/status/1490849911696666625/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "small": {
#                                 "w": 578,
#                                 "h": 680,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 1020,
#                                 "h": 1200,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1080,
#                                 "h": 1270,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 839262857032155137,
#                 "id_str": "839262857032155137",
#                 "name": "EMMA",
#                 "screen_name": "glitter_2em13",
#                 "location": "",
#                 "description": "I love Art , Quote, Animal, Nature, BFF\u25aa\ufe0fAll credit for Videos and Photos aren't mine",
#                 "url": "https://t.co/JhxFFwNg2j",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/JhxFFwNg2j",
#                                 "expanded_url": "https://twitter.com/search?q=%E2%80%AAFrom%3Aglitter_2em13%20%E2%80%AC&src=typed_query",
#                                 "display_url": "twitter.com/search?q=%E2%8\u2026",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 157691,
#                 "friends_count": 3547,
#                 "listed_count": 349,
#                 "created_at": "Tue Mar 07 23:53:52 +0000 2017",
#                 "favourites_count": 573873,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 644351,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1454898874775408640/ck5ORF9B_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1454898874775408640/ck5ORF9B_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/839262857032155137/1643812420",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 95,
#             "favorite_count": 1162,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 95,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Tue Feb 08 01:58:03 +0000 2022",
#         "id": 1490867490229866496,
#         "id_str": "1490867490229866496",
#         "text": "RT @COLORS0506: \u30b9\u30c6\u30c3\u30ab\u30fc\u30d7\u30ec\u30bc\u30f3\u30c8\u4f01\u753b\ud83d\ude46\n\u53c2\u52a0\u65b9\u6cd5\n\u3044\u3044\u306d\u3001\u30d5\u30a9\u30ed\u30fc\u3001RT\ud83d\udc4d\n\u30b3\u30e1\u30f3\u30c8\u304c\u3042\u308c\u3070\u5f53\u9078\u7387UP\ud83d\ude46\n10\u540d\u69d8\u3067\u8003\u3048\u3066\u304a\u308a\u307e\u3059\ud83d\ude0f\n#\u30ab\u30b9\u30bf\u30e0\u30da\u30a4\u30f3\u30c8\n#\u30c8\u30fc\u30bf\u30eb\u30da\u30a4\u30f3\u30c8\n#\u30ab\u30e9\u30fc\u30ba\n#KTS\n#em\n#\u30b9\u30c6\u30c3\u30ab\u30fc\u30d7\u30ec\u30bc\u30f3\u30c8\u4f01\u753b\n#\u5f53\u9078\u8005\u306b\n#\u7279\u5225\u4f01\u753b\u3042\u308a\u2026",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "\u30ab\u30b9\u30bf\u30e0\u30da\u30a4\u30f3\u30c8",
#                     "indices": [
#                         77,
#                         86
#                     ]
#                 },
#                 {
#                     "text": "\u30c8\u30fc\u30bf\u30eb\u30da\u30a4\u30f3\u30c8",
#                     "indices": [
#                         87,
#                         96
#                     ]
#                 },
#                 {
#                     "text": "\u30ab\u30e9\u30fc\u30ba",
#                     "indices": [
#                         97,
#                         102
#                     ]
#                 },
#                 {
#                     "text": "KTS",
#                     "indices": [
#                         103,
#                         107
#                     ]
#                 },
#                 {
#                     "text": "em",
#                     "indices": [
#                         108,
#                         111
#                     ]
#                 },
#                 {
#                     "text": "\u30b9\u30c6\u30c3\u30ab\u30fc\u30d7\u30ec\u30bc\u30f3\u30c8\u4f01\u753b",
#                     "indices": [
#                         112,
#                         125
#                     ]
#                 },
#                 {
#                     "text": "\u5f53\u9078\u8005\u306b",
#                     "indices": [
#                         126,
#                         131
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "COLORS0506",
#                     "name": "custompaint Colors",
#                     "id": 1101500915780005894,
#                     "id_str": "1101500915780005894",
#                     "indices": [
#                         3,
#                         14
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "ja",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1385195790168059905,
#             "id_str": "1385195790168059905",
#             "name": "\u3088\u3046",
#             "screen_name": "z23f6NYIou5EOyq",
#             "location": "",
#             "description": "",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 13,
#             "friends_count": 37,
#             "listed_count": 1,
#             "created_at": "Thu Apr 22 11:36:41 +0000 2021",
#             "favourites_count": 8,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 11,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1385200298973548550/rJSnXqT4_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1385200298973548550/rJSnXqT4_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Feb 07 14:47:04 +0000 2022",
#             "id": 1490698634555699203,
#             "id_str": "1490698634555699203",
#             "text": "\u30b9\u30c6\u30c3\u30ab\u30fc\u30d7\u30ec\u30bc\u30f3\u30c8\u4f01\u753b\ud83d\ude46\n\u53c2\u52a0\u65b9\u6cd5\n\u3044\u3044\u306d\u3001\u30d5\u30a9\u30ed\u30fc\u3001RT\ud83d\udc4d\n\u30b3\u30e1\u30f3\u30c8\u304c\u3042\u308c\u3070\u5f53\u9078\u7387UP\ud83d\ude46\n10\u540d\u69d8\u3067\u8003\u3048\u3066\u304a\u308a\u307e\u3059\ud83d\ude0f\n#\u30ab\u30b9\u30bf\u30e0\u30da\u30a4\u30f3\u30c8\n#\u30c8\u30fc\u30bf\u30eb\u30da\u30a4\u30f3\u30c8\n#\u30ab\u30e9\u30fc\u30ba\n#KTS\n#em\n#\u30b9\u30c6\u30c3\u30ab\u30fc\u30d7\u30ec\u30bc\u30f3\u30c8\u4f01\u753b\n#\u5f53\u9078\u8005\u306b\u2026 https://t.co/j7F6qIyBhu",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "\u30ab\u30b9\u30bf\u30e0\u30da\u30a4\u30f3\u30c8",
#                         "indices": [
#                             61,
#                             70
#                         ]
#                     },
#                     {
#                         "text": "\u30c8\u30fc\u30bf\u30eb\u30da\u30a4\u30f3\u30c8",
#                         "indices": [
#                             71,
#                             80
#                         ]
#                     },
#                     {
#                         "text": "\u30ab\u30e9\u30fc\u30ba",
#                         "indices": [
#                             81,
#                             86
#                         ]
#                     },
#                     {
#                         "text": "KTS",
#                         "indices": [
#                             87,
#                             91
#                         ]
#                     },
#                     {
#                         "text": "em",
#                         "indices": [
#                             92,
#                             95
#                         ]
#                     },
#                     {
#                         "text": "\u30b9\u30c6\u30c3\u30ab\u30fc\u30d7\u30ec\u30bc\u30f3\u30c8\u4f01\u753b",
#                         "indices": [
#                             96,
#                             109
#                         ]
#                     },
#                     {
#                         "text": "\u5f53\u9078\u8005\u306b",
#                         "indices": [
#                             110,
#                             115
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/j7F6qIyBhu",
#                         "expanded_url": "https://twitter.com/i/web/status/1490698634555699203",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             117,
#                             140
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "ja",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1101500915780005894,
#                 "id_str": "1101500915780005894",
#                 "name": "custompaint Colors",
#                 "screen_name": "COLORS0506",
#                 "location": "",
#                 "description": "\u516b\u5343\u4ee3\u7dcf\u672c\u5c71 \u30ab\u30e9\u30fc\u30ba                                                                                  \n\u30ab\u30b9\u30bf\u30e0\u30da\u30a4\u30f3\u30c8 \n\u30e9\u30e1 \u30ad\u30e3\u30f3\u30c7\u30a3 \u4f55\u3067\u3082\u3067\u304d\u307e\u3059\ud83d\ude0b\n\u6620\u753b \u300c\u4e0b\u59bb\u7269\u8a9e\u300d\u300c\u30e4\u30f3\u30ad\u30fc\u5973\u5b50\u9ad8\u751f\u300d\n\u51fa\u6f14\u8eca\u4e21\u30da\u30a4\u30f3\u30c8",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 2254,
#                 "friends_count": 2296,
#                 "listed_count": 12,
#                 "created_at": "Fri Mar 01 15:14:18 +0000 2019",
#                 "favourites_count": 1629,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 1334,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1328913077627076610/gAX1Z6vP_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1328913077627076610/gAX1Z6vP_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1101500915780005894/1611937358",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 93,
#             "favorite_count": 111,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "ja"
#         },
#         "is_quote_status": false,
#         "retweet_count": 93,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "ja"
#     },
#     {
#         "created_at": "Tue Feb 08 01:56:58 +0000 2022",
#         "id": 1490867219123040256,
#         "id_str": "1490867219123040256",
#         "text": "RT @glitter_2em13: Stress less and enjoy the best\n                                      \u3002 .\u3002\u25ef*\uff0a\u309c\n\n#em https://t.co/WMbrSlobPK",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "em",
#                     "indices": [
#                         98,
#                         101
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "glitter_2em13",
#                     "name": "EMMA",
#                     "id": 839262857032155137,
#                     "id_str": "839262857032155137",
#                     "indices": [
#                         3,
#                         17
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1490849908961984512,
#                     "id_str": "1490849908961984512",
#                     "indices": [
#                         102,
#                         125
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                     "url": "https://t.co/WMbrSlobPK",
#                     "display_url": "pic.twitter.com/WMbrSlobPK",
#                     "expanded_url": "https://twitter.com/glitter_2em13/status/1490849911696666625/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 578,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1020,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1080,
#                             "h": 1270,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490849911696666625,
#                     "source_status_id_str": "1490849911696666625",
#                     "source_user_id": 839262857032155137,
#                     "source_user_id_str": "839262857032155137"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490849908961984512,
#                     "id_str": "1490849908961984512",
#                     "indices": [
#                         102,
#                         125
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                     "url": "https://t.co/WMbrSlobPK",
#                     "display_url": "pic.twitter.com/WMbrSlobPK",
#                     "expanded_url": "https://twitter.com/glitter_2em13/status/1490849911696666625/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 578,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1020,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1080,
#                             "h": 1270,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490849911696666625,
#                     "source_status_id_str": "1490849911696666625",
#                     "source_user_id": 839262857032155137,
#                     "source_user_id_str": "839262857032155137"
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1463587270187966468,
#             "id_str": "1463587270187966468",
#             "name": "Tomy Pannetier\ud83c\uddf2\ud83c\uddeb\ud83d\ude07\ud83d\ude4f\ud83d\udc78\ud83d\udca6\ud83d\ude3d\ud83c\udf31\ud83c\udf40\ud83c\udf33\ud83e\udeb4 \ud83c\udfde\ufe0f\ud83c\udf0d\ud83d\udc8c\ud83c\udf04\ud83c\uddf2\ud83c\uddeb",
#             "screen_name": "tomypannetier1",
#             "location": "",
#             "description": "Bonne personne vrai gentil calme ange \u00e9ternel",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 731,
#             "friends_count": 1946,
#             "listed_count": 0,
#             "created_at": "Wed Nov 24 19:16:42 +0000 2021",
#             "favourites_count": 13581,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 16736,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1464101314414190593/SXs1VLyi_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1464101314414190593/SXs1VLyi_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1463587270187966468/1637903930",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Tue Feb 08 00:48:12 +0000 2022",
#             "id": 1490849911696666625,
#             "id_str": "1490849911696666625",
#             "text": "Stress less and enjoy the best\n                                      \u3002 .\u3002\u25ef*\uff0a\u309c\n\n#em https://t.co/WMbrSlobPK",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "em",
#                         "indices": [
#                             79,
#                             82
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1490849908961984512,
#                         "id_str": "1490849908961984512",
#                         "indices": [
#                             83,
#                             106
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                         "url": "https://t.co/WMbrSlobPK",
#                         "display_url": "pic.twitter.com/WMbrSlobPK",
#                         "expanded_url": "https://twitter.com/glitter_2em13/status/1490849911696666625/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "small": {
#                                 "w": 578,
#                                 "h": 680,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 1020,
#                                 "h": 1200,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1080,
#                                 "h": 1270,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1490849908961984512,
#                         "id_str": "1490849908961984512",
#                         "indices": [
#                             83,
#                             106
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                         "url": "https://t.co/WMbrSlobPK",
#                         "display_url": "pic.twitter.com/WMbrSlobPK",
#                         "expanded_url": "https://twitter.com/glitter_2em13/status/1490849911696666625/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "small": {
#                                 "w": 578,
#                                 "h": 680,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 1020,
#                                 "h": 1200,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1080,
#                                 "h": 1270,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 839262857032155137,
#                 "id_str": "839262857032155137",
#                 "name": "EMMA",
#                 "screen_name": "glitter_2em13",
#                 "location": "",
#                 "description": "I love Art , Quote, Animal, Nature, BFF\u25aa\ufe0fAll credit for Videos and Photos aren't mine",
#                 "url": "https://t.co/JhxFFwNg2j",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/JhxFFwNg2j",
#                                 "expanded_url": "https://twitter.com/search?q=%E2%80%AAFrom%3Aglitter_2em13%20%E2%80%AC&src=typed_query",
#                                 "display_url": "twitter.com/search?q=%E2%8\u2026",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 157691,
#                 "friends_count": 3547,
#                 "listed_count": 349,
#                 "created_at": "Tue Mar 07 23:53:52 +0000 2017",
#                 "favourites_count": 573873,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 644351,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1454898874775408640/ck5ORF9B_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1454898874775408640/ck5ORF9B_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/839262857032155137/1643812420",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 95,
#             "favorite_count": 1162,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 95,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Tue Feb 08 01:55:12 +0000 2022",
#         "id": 1490866774237237250,
#         "id_str": "1490866774237237250",
#         "text": "RT @glitter_2em13: Stress less and enjoy the best\n                                      \u3002 .\u3002\u25ef*\uff0a\u309c\n\n#em https://t.co/WMbrSlobPK",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "em",
#                     "indices": [
#                         98,
#                         101
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "glitter_2em13",
#                     "name": "EMMA",
#                     "id": 839262857032155137,
#                     "id_str": "839262857032155137",
#                     "indices": [
#                         3,
#                         17
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1490849908961984512,
#                     "id_str": "1490849908961984512",
#                     "indices": [
#                         102,
#                         125
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                     "url": "https://t.co/WMbrSlobPK",
#                     "display_url": "pic.twitter.com/WMbrSlobPK",
#                     "expanded_url": "https://twitter.com/glitter_2em13/status/1490849911696666625/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 578,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1020,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1080,
#                             "h": 1270,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490849911696666625,
#                     "source_status_id_str": "1490849911696666625",
#                     "source_user_id": 839262857032155137,
#                     "source_user_id_str": "839262857032155137"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490849908961984512,
#                     "id_str": "1490849908961984512",
#                     "indices": [
#                         102,
#                         125
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLCQF-UaQAA5YBW.jpg",
#                     "url": "https://t.co/WMbrSlobPK",
#                     "display_url": "pic.twitter.com/WMbrSlobPK",
#                     "expanded_url": "https://twitter.com/glitter_2em13/status/1490849911696666625/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 578,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1020,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1080,
#                             "h": 1270,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490849911696666625,
#                     "source_status_id_str": "1490849911696666625",
#                     "source_user_id": 839262857032155137,
#                     "source_user_id_str": "839262857032155137"
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1111933974115483648,
#             "id_str": "1111933974115483648",
#             "name": "\ud83c\udf39Hamoodie\ud83c\udf39",
#             "screen_name": "Moody760Moody",
#             "location": "",
# ...
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1100958767380905984/1555694047",
#             "profile_link_color": "1B95E0",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "ht"
#     },
#     {
#         "created_at": "Sun Feb 06 21:59:24 +0000 2022",
#         "id": 1490445044763013124,
#         "id_str": "1490445044763013124",
#         "text": "G\u00f2l Marco Asensio nan 74\u00e8m minit bay ekip R\u00e9al Madrid la viktwa kont ekip Granada nan kad 23\u00e8m jounen La Liga a https://t.co/ZKktWqmBgC",
#         "truncated": false,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/ZKktWqmBgC",
#                     "expanded_url": "https://www.instagram.com/p/CZpty4gLrdA/?utm_medium=twitter",
#                     "display_url": "instagram.com/p/CZpty4gLrdA/\u2026",
#                     "indices": [
#                         112,
#                         135
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "ht",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1100958767380905984,
#             "id_str": "1100958767380905984",
#             "name": "Biwww",
#             "screen_name": "Biwwwsports",
#             "location": "",
#             "description": "Donate ?https://t.co/w1Lx9WcC45",
#             "url": "https://t.co/TztFid9Oql",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/TztFid9Oql",
#                             "expanded_url": "https://www.youtube.com/channel/UCnmXGi8ZaLnnTECVUFyQh9A",
#                             "display_url": "youtube.com/channel/UCnmXG\u2026",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/w1Lx9WcC45",
#                             "expanded_url": "https://www.paypal.me/biwww",
#                             "display_url": "paypal.me/biwww",
#                             "indices": [
#                                 8,
#                                 31
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 414,
#             "friends_count": 236,
#             "listed_count": 0,
#             "created_at": "Thu Feb 28 03:19:59 +0000 2019",
#             "favourites_count": 191,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 2839,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1117982082184163329/GnUJ-ffS_normal.png",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1117982082184163329/GnUJ-ffS_normal.png",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1100958767380905984/1555694047",
#             "profile_link_color": "1B95E0",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "ht"
#     },
#     {
#         "created_at": "Fri Feb 04 08:41:50 +0000 2022",
#         "id": 1489519554216800257,
#         "id_str": "1489519554216800257",
#         "text": "Studie: Hohe Impfbereitschaft bei Migranten via https://t.co/1RatnRH58x @MiGAZIN @epd_news",
#         "truncated": false,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "MiGAZIN",
#                     "name": "MiGAZIN",
#                     "id": 21043853,
#                     "id_str": "21043853",
#                     "indices": [
#                         72,
#                         80
#                     ]
#                 },
#                 {
#                     "screen_name": "epd_news",
#                     "name": "epd",
#                     "id": 1363007672,
#                     "id_str": "1363007672",
#                     "indices": [
#                         81,
#                         90
#                     ]
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "https://t.co/1RatnRH58x",
#                     "expanded_url": "http://u.epd.de/23em",
#                     "display_url": "u.epd.de/23em",
#                     "indices": [
#                         48,
#                         71
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "de",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1127867502376173569,
#             "id_str": "1127867502376173569",
#             "name": "epd sozial",
#             "screen_name": "epdsozial",
#             "location": "Frankfurt am Main, Deutschland",
#             "description": "Hier twittert der Fachdienst des Evangelischen Pressedienstes (epd) f\u00fcr die Sozialbranche",
#             "url": "https://t.co/b36670hZje",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/b36670hZje",
#                             "expanded_url": "https://www.epd.de/fachdienst/sozial/startseite",
#                             "display_url": "epd.de/fachdienst/soz\u2026",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 1008,
#             "friends_count": 510,
#             "listed_count": 16,
#             "created_at": "Mon May 13 09:25:42 +0000 2019",
#             "favourites_count": 7322,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 6145,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1127887153273495552/yCfGNvbF_normal.png",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1127887153273495552/yCfGNvbF_normal.png",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1127867502376173569/1571390763",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 1,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "de"
#     },
#     {
#         "created_at": "Wed Feb 02 18:44:53 +0000 2022",
#         "id": 1488946540421038100,
#         "id_str": "1488946540421038100",
#         "text": "tanmen pou redefini vizyon sila sou jw\u00e8t. \nSerena Williams, gwo atl\u00e8t, nan tout dimansyon mo a, ki rive pran 23\u00e8m t\u2026 https://t.co/6eiBoIupJg",
#         "truncated": true,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/6eiBoIupJg",
#                     "expanded_url": "https://twitter.com/i/web/status/1488946540421038100",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         117,
#                         140
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "ht",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": 1488946532581847042,
#         "in_reply_to_status_id_str": "1488946532581847042",
#         "in_reply_to_user_id": 4704474008,
#         "in_reply_to_user_id_str": "4704474008",
#         "in_reply_to_screen_name": "Simeonkokorat",
#         "user": {
#             "id": 4704474008,
#             "id_str": "4704474008",
#             "name": "D'johensby SIM\u00c9ON",
#             "screen_name": "Simeonkokorat",
#             "location": "Haiti",
#             "description": "Ayisyen ,N\u00e8g Site Sol\u00e8y,  N\u00e8g lari, Grapyay, Kokorat etidyan nan Mast\u00e8 filozofi. Fanatik Resin, Liv\u00e8poul, Reyal, Mas\u00e8y, AS Woma, Lebron, Nadal.",
#             "url": "https://t.co/uXOdyi52j8",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/uXOdyi52j8",
#                             "expanded_url": "http://Simeondjohensby.yahoo.fr",
#                             "display_url": "Simeondjohensby.yahoo.fr",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 4615,
#             "friends_count": 2157,
#             "listed_count": 4,
#             "created_at": "Sun Jan 03 18:50:07 +0000 2016",
#             "favourites_count": 54275,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 78967,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1469309461210832896/iJrt59li_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1469309461210832896/iJrt59li_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/4704474008/1629403198",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": {
#             "id": "d3e226ca18cd4ae8",
#             "url": "https://api.twitter.com/1.1/geo/id/d3e226ca18cd4ae8.json",
#             "place_type": "country",
#             "name": "Haiti",
#             "full_name": "Haiti",
#             "country_code": "HT",
#             "country": "Haiti",
#             "contained_within": [],
#             "bounding_box": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -74.4798235,
#                             18.0214258
#                         ],
#                         [
#                             -71.6284598,
#                             18.0214258
#                         ],
#                         [
#                             -71.6284598,
#                             20.0894352
#                         ],
#                         [
#                             -74.4798235,
#                             20.0894352
#                         ]
#                     ]
#                 ]
#             },
#             "attributes": {}
#         },
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "ht"
#     }
# ]
